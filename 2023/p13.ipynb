# %%
from aocd.models import Puzzle

puzzle = Puzzle(year=2023, day=13)

def parses(input):
    def parse_group(group):
        return [['.#'.index(val) for val in row] for row in group.split('\n')]
    groups = input.strip().split('\n\n')
    return [parse_group(group) for group in groups]

# import re
# def parses(input):
#     return [int(re.findall('\d', line)) for line in nput.strip().split('\n')]

data = parses(puzzle.input_data)

# %%
sample = parses("""#.##..##.
..#.##.#.
##......#
##......#
..#.##.#.
..##..##.
#.#.##.#.

#...##..#
#....#..#
..##..###
#####.##.
#####.##.
..##..###
#....#..#
""")

# %%
data = sample

# %%
def solve_a(data):
    total = 0
    for p, pattern in enumerate(data):
        pattern = np.array(pattern, dtype=np.int8)
        total_before = total
        for matrix, offset in [(pattern, 100), (pattern.T, 1)]:
            N = matrix.shape[0]
            for i in range(1,N):
                j = N-i
                k = min(i,j)
                A = matrix[i-k:i]
                B = matrix[i:i+k][::-1]
                if (A==B).all():
#                     plt.imshow(pattern)
#                     if offset == 100:
#                         plt.axhline(i-0.5)
#                     else:
#                         plt.axvline(i-0.5)
#                     plt.title(f"{p}: {offset * i}")
#                     plt.show()
                    total += offset * i
        if total_before == total:
            plt.imshow(matrix)
            plt.title(f"{p}: ERROR ⚠️")
            plt.show()

    return total

# %%
solve_a(sample)
# Out:
# 405

# %%
solve_a(data)
# Out:
# 31265

# %%
plt.imshow(np.array(sample[1], dtype=np.uint8))

# %%
plt.imshow(np.array(sample[0], dtype=np.uint8))

# %%
matrix = np.array(data[3], dtype=np.int8)
N = matrix.shape[0]

plt.imshow(matrix)
# plt.axhline(5.5)
plt.show()



for i in range(1,N):
    j = N-i
    k = min(i,j)
    A = matrix[i-k:i]
    B = matrix[i:i+k][::-1]
    diff = abs(A-B)
#     if diff.sum() == 1:
#         a, b = np.unravel_index(np.argmax(diff), diff.shape)
#         print(a,b)
    plt.imshow(abs(A-B))
    plt.title(f"{i} {abs(A-B).sum()}")
    plt.show()
#     if (A==B).all():
#         print(i)

# %%
def solve_b(data):
    total = 0
    for p, pattern in enumerate(data):
        pattern = np.array(pattern, dtype=np.int8)
        total_before = total
        diffs = []
        for matrix, offset in [(pattern, 100), (pattern.T, 1)]:
            N = matrix.shape[0]
            for i in range(1,N):
                j = N-i
                k = min(i,j)
                A = matrix[i-k:i]
                B = matrix[i:i+k][::-1]
                diffs.append(abs(A-B).sum())
                if abs(A-B).sum() == 1:
#                     plt.imshow(pattern)
#                     if offset == 100:
#                         plt.axhline(i-0.5)
#                     else:
#                         plt.axvline(i-0.5)
#                     plt.title(f"{p}: {offset * i}")
#                     plt.show()
                    total += offset * i
        if total_before == total:
            plt.imshow(matrix)
            plt.title(f"{p}: ERROR ⚠️")
            print(diffs)
            plt.show()

    return total

# %%
solve_b(sample)
# Out:
# 400

# %%
solve_b(data)
# Out:
# 39359

# %%
plt.imshow(data[1])

# %%
def solve_a(data):
    pass

# %%
def solve_b(data):
    pass
